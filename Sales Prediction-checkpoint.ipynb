# %% [markdown]
# # SALES PREDICTION

# %%
#iMPORT REQUIRED LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load Dataset
df=pd.read_csv("Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#Data Pre-processing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
#Check for missing/null values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# NO MISSING VALUES FOUND

# %%
#EXPLORATORY DATA ANALYSIS
sns.pairplot(df, vars=['TV', 'Radio', 'Newspaper', 'Sales'])
plt.show()

# %%
 #Correlation heatmap to check feature correlations
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix)
plt.title('Correlation Heatmap')
plt.show()

# %%
#SELECTING TARGET VARIABLE
X=df.iloc[:,[0,1,2,3]].values
Y=df.iloc[:,[4]].values

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=182)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#PREDICTION
Y_pred=model.predict(X_test)

# %%
#REGRESSION PLOT
sns.regplot(Y_test,Y_pred,label=['Data Points'])

plt.title('PRODUCT VS SALES')
plt.xlabel("PRODUCTS")
plt.ylabel("SALES")
plt.legend()

plt.show()

# %%
#MODEL EVALUATION
from sklearn.metrics import mean_squared_error,r2_score
accuracy=mean_squared_error(Y_test,Y_pred)
print("Mean-Squared-Error=",accuracy)
# Out:
# Mean-Squared-Error= 2.4757383149886505

# %%
acc2=r2_score(Y_test,Y_pred)
print("R-Squarred or coefficient of determination=",acc2)
# Out:
# R-Squarred or coefficient of determination= 0.918931462994798

# %% [markdown]
# The higher the R2 value and the lower the MSE/RMSE values, the better the linear regression model is at predicting the target variable.

# %% [markdown]
# # Thank You!
